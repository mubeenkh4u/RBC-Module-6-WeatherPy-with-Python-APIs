# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 792

# %%
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
new_city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_conditions = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        new_city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_conditions})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")


# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(new_city_data)
#print(city_data_df.head(10))

# New Column Order
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
#city_data_df.head(10)

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | godean
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | hervey bay
# Processing Record 5 of Set 1 | jeremoabo
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | port hedland
# Processing Record 9 of Set 1 | beruni
# City not found. Skipping...
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | sakakah
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | cascais
# Processing Record 18 of Set 1 | nanga eboko
# Processing Record 19 of Set 1 | tiarei
# Processing Record 20 of Set 1 | okuchi
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | bandarbeyla
# Processing Record 23 of Set 1 | norrtalje
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | corn island
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | korla
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | biak
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | acajutla
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | sergeyevka
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | gerash
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | arcata
# Processing Record 43 of Set 1 | plymouth
# Processing Record 44 of Set 1 | chuy
# Processing Record 45 of Set 1 | berlevag
# Processing Record 46 of Set 1 | coruripe
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | sinnamary
# Processing Record 49 of Set 1 | lorengau
# Processing Record 50 of Set 1 | havre-saint-pierre
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | mujiayingzi
# Processing Record 3 of Set 2 | nago
# Processing Record 4 of Set 2 | shimoda
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | atambua
# Processing Record 8 of Set 2 | correntina
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | new plymouth
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | lavrentiya
# Processing Record 14 of Set 2 | nizhniy kuranakh
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | umm kaddadah
# Processing Record 18 of Set 2 | bucerias
# Processing Record 19 of Set 2 | agadir
# Processing Record 20 of Set 2 | plettenberg bay
# Processing Record 21 of Set 2 | lata
# Processing Record 22 of Set 2 | tieling
# Processing Record 23 of Set 2 | kuryk
# Processing Record 24 of Set 2 | richards bay
# Processing Record 25 of Set 2 | molo
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | margate
# Processing Record 29 of Set 2 | labuhan
# Processing Record 30 of Set 2 | port blair
# Processing Record 31 of Set 2 | yerbogachen
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | ostrovnoy
# Processing Record 34 of Set 2 | monzon
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | dagata
# City not found. Skipping...
# Processing Record 38 of Set 2 | boa vista
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | manjacaze
# Processing Record 41 of Set 2 | sept-iles
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | akyab
# Processing Record 45 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 46 of Set 2 | kitimat
# Processing Record 47 of Set 2 | kawalu
# Processing Record 48 of Set 2 | padang
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | kauhajoki
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | abha
# Processing Record 6 of Set 3 | maryborough
# Processing Record 7 of Set 3 | yebaishou
# Processing Record 8 of Set 3 | luderitz
# Processing Record 9 of Set 3 | baruun-urt
# Processing Record 10 of Set 3 | slavicin
# Processing Record 11 of Set 3 | tamboril
# Processing Record 12 of Set 3 | haverfordwest
# Processing Record 13 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | tupik
# Processing Record 16 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 3 | juneau
# Processing Record 20 of Set 3 | gamba
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | kapaa
# Processing Record 24 of Set 3 | darnah
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | jalu
# Processing Record 30 of Set 3 | araouane
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | vostochnyy
# Processing Record 33 of Set 3 | mogzon
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | sola
# Processing Record 36 of Set 3 | micheweni
# Processing Record 37 of Set 3 | kahului
# Processing Record 38 of Set 3 | portland
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | champerico
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | grand gaube
# Processing Record 43 of Set 3 | deputatskiy
# Processing Record 44 of Set 3 | prince rupert
# Processing Record 45 of Set 3 | haines junction
# Processing Record 46 of Set 3 | sumbe
# Processing Record 47 of Set 3 | praia
# Processing Record 48 of Set 3 | muros
# Processing Record 49 of Set 3 | isangel
# Processing Record 50 of Set 3 | shache
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | sao joao da barra
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | puerto carreno
# Processing Record 6 of Set 4 | mexicali
# Processing Record 7 of Set 4 | college
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | tam ky
# Processing Record 11 of Set 4 | seymchan
# Processing Record 12 of Set 4 | fryanovo
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 4 | treinta y tres
# Processing Record 18 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 4 | pingliang
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | hay river
# Processing Record 22 of Set 4 | buchanan
# Processing Record 23 of Set 4 | zyryanka
# Processing Record 24 of Set 4 | la libertad
# Processing Record 25 of Set 4 | kirovskiy
# Processing Record 26 of Set 4 | najran
# Processing Record 27 of Set 4 | oxbow
# Processing Record 28 of Set 4 | verkhnevilyuysk
# Processing Record 29 of Set 4 | lucapa
# Processing Record 30 of Set 4 | fortuna
# Processing Record 31 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 4 | kant
# Processing Record 33 of Set 4 | brandon
# Processing Record 34 of Set 4 | bereda
# Processing Record 35 of Set 4 | novomykolayivka
# Processing Record 36 of Set 4 | natal
# Processing Record 37 of Set 4 | liuzhou
# Processing Record 38 of Set 4 | necochea
# Processing Record 39 of Set 4 | kargopol
# Processing Record 40 of Set 4 | castro
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | kichera
# Processing Record 45 of Set 4 | sotnikovo
# Processing Record 46 of Set 4 | nerchinskiy zavod
# Processing Record 47 of Set 4 | hualmay
# Processing Record 48 of Set 4 | codrington
# Processing Record 49 of Set 4 | san luis
# Processing Record 50 of Set 4 | russell
# Processing Record 1 of Set 5 | benalla
# Processing Record 2 of Set 5 | usinsk
# Processing Record 3 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 5 | nouadhibou
# Processing Record 5 of Set 5 | sibut
# Processing Record 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5 | gabu
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 10 of Set 5 | kavaratti
# Processing Record 11 of Set 5 | bonnyville
# Processing Record 12 of Set 5 | guerrero negro
# Processing Record 13 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 14 of Set 5 | eureka
# Processing Record 15 of Set 5 | umm lajj
# Processing Record 16 of Set 5 | diego de almagro
# Processing Record 17 of Set 5 | port shepstone
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | cayenne
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | san quintin
# Processing Record 23 of Set 5 | laguna
# Processing Record 24 of Set 5 | hami
# Processing Record 25 of Set 5 | kendari
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | dikson
# Processing Record 28 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 5 | tefe
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | nalobikha
# Processing Record 32 of Set 5 | kimbe
# Processing Record 33 of Set 5 | ryotsu
# Processing Record 34 of Set 5 | saint-francois
# Processing Record 35 of Set 5 | roebourne
# Processing Record 36 of Set 5 | turka
# Processing Record 37 of Set 5 | mount isa
# Processing Record 38 of Set 5 | kutum
# Processing Record 39 of Set 5 | mormugao
# Processing Record 40 of Set 5 | boli
# Processing Record 41 of Set 5 | nabire
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | jeremie
# Processing Record 44 of Set 5 | blagoveshchensk
# Processing Record 45 of Set 5 | trencin
# Processing Record 46 of Set 5 | husavik
# Processing Record 47 of Set 5 | valparaiso
# Processing Record 48 of Set 5 | maniitsoq
# Processing Record 49 of Set 5 | moba
# Processing Record 50 of Set 5 | tateyama
# Processing Record 1 of Set 6 | mayo
# Processing Record 2 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 6 | baoning
# Processing Record 4 of Set 6 | cherskiy
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | saint-philippe
# Processing Record 8 of Set 6 | dickinson
# Processing Record 9 of Set 6 | constitucion
# Processing Record 10 of Set 6 | ahipara
# Processing Record 11 of Set 6 | kasama
# Processing Record 12 of Set 6 | alofi
# Processing Record 13 of Set 6 | dire dawa
# Processing Record 14 of Set 6 | campoverde
# Processing Record 15 of Set 6 | mahibadhoo
# Processing Record 16 of Set 6 | dalkola
# Processing Record 17 of Set 6 | inuvik
# Processing Record 18 of Set 6 | bonavista
# Processing Record 19 of Set 6 | banes
# Processing Record 20 of Set 6 | ures
# Processing Record 21 of Set 6 | verkhovazhye
# Processing Record 22 of Set 6 | san ramon
# Processing Record 23 of Set 6 | north branch
# Processing Record 24 of Set 6 | kedrovyy
# Processing Record 25 of Set 6 | vao
# Processing Record 26 of Set 6 | zarubino
# Processing Record 27 of Set 6 | kingsland
# Processing Record 28 of Set 6 | ust-kan
# Processing Record 29 of Set 6 | prado
# Processing Record 30 of Set 6 | nizhnevartovsk
# Processing Record 31 of Set 6 | beringovskiy
# Processing Record 32 of Set 6 | gualaceo
# Processing Record 33 of Set 6 | tuktoyaktuk
# Processing Record 34 of Set 6 | tianpeng
# Processing Record 35 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 6 | alenquer
# Processing Record 37 of Set 6 | wenling
# Processing Record 38 of Set 6 | pemberton
# Processing Record 39 of Set 6 | merauke
# Processing Record 40 of Set 6 | westport
# Processing Record 41 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | garden city
# Processing Record 43 of Set 6 | henties bay
# Processing Record 44 of Set 6 | peniche
# Processing Record 45 of Set 6 | egvekinot
# Processing Record 46 of Set 6 | vilhena
# Processing Record 47 of Set 6 | nynashamn
# Processing Record 48 of Set 6 | lucea
# Processing Record 49 of Set 6 | rafsanjan
# Processing Record 50 of Set 6 | derzhavinsk
# Processing Record 1 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 7 | nelson bay
# Processing Record 3 of Set 7 | tabas
# Processing Record 4 of Set 7 | yithion
# City not found. Skipping...
# Processing Record 5 of Set 7 | karaton
# Processing Record 6 of Set 7 | znamenskoye
# Processing Record 7 of Set 7 | bretten
# Processing Record 8 of Set 7 | yeniseysk
# Processing Record 9 of Set 7 | zaragoza
# Processing Record 10 of Set 7 | conde
# Processing Record 11 of Set 7 | avera
# Processing Record 12 of Set 7 | tessalit
# Processing Record 13 of Set 7 | namagiripettai
# Processing Record 14 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 7 | rodrigues alves
# Processing Record 16 of Set 7 | chase
# Processing Record 17 of Set 7 | entre rios
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | flinders
# Processing Record 20 of Set 7 | namatanai
# Processing Record 21 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 7 | carnarvon
# Processing Record 23 of Set 7 | silifke
# Processing Record 24 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 7 | jacareacanga
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | charters towers
# Processing Record 28 of Set 7 | sabalgarh
# Processing Record 29 of Set 7 | kangaatsiaq
# Processing Record 30 of Set 7 | namie
# Processing Record 31 of Set 7 | soavinandriana
# Processing Record 32 of Set 7 | marzuq
# Processing Record 33 of Set 7 | cairns
# Processing Record 34 of Set 7 | gizo
# Processing Record 35 of Set 7 | mombetsu
# Processing Record 36 of Set 7 | teberda
# Processing Record 37 of Set 7 | ippy
# Processing Record 38 of Set 7 | arman
# Processing Record 39 of Set 7 | saurimo
# Processing Record 40 of Set 7 | burns lake
# Processing Record 41 of Set 7 | inhambane
# Processing Record 42 of Set 7 | roald
# Processing Record 43 of Set 7 | goderich
# Processing Record 44 of Set 7 | adrar
# Processing Record 45 of Set 7 | xam nua
# Processing Record 46 of Set 7 | den helder
# Processing Record 47 of Set 7 | stornoway
# Processing Record 48 of Set 7 | isa khel
# Processing Record 49 of Set 7 | luangwa
# Processing Record 50 of Set 7 | oranjemund
# Processing Record 1 of Set 8 | kasganj
# Processing Record 2 of Set 8 | kodiak
# Processing Record 3 of Set 8 | hays
# Processing Record 4 of Set 8 | rudbar
# Processing Record 5 of Set 8 | cidreira
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | kozhva
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | floro
# Processing Record 10 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 8 | nueve de julio
# Processing Record 12 of Set 8 | mastic beach
# Processing Record 13 of Set 8 | lososina
# Processing Record 14 of Set 8 | talcahuano
# Processing Record 15 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 16 of Set 8 | adwa
# Processing Record 17 of Set 8 | magalia
# Processing Record 18 of Set 8 | khatanga
# Processing Record 19 of Set 8 | ambilobe
# Processing Record 20 of Set 8 | tuy hoa
# Processing Record 21 of Set 8 | fairbanks
# Processing Record 22 of Set 8 | san juan del sur
# Processing Record 23 of Set 8 | meadow lake
# Processing Record 24 of Set 8 | kirakira
# Processing Record 25 of Set 8 | inta
# Processing Record 26 of Set 8 | port moresby
# Processing Record 27 of Set 8 | paratinga
# Processing Record 28 of Set 8 | liverpool
# Processing Record 29 of Set 8 | chimbote
# Processing Record 30 of Set 8 | torbay
# Processing Record 31 of Set 8 | port augusta
# Processing Record 32 of Set 8 | korfovskiy
# Processing Record 33 of Set 8 | san cristobal
# Processing Record 34 of Set 8 | san roque
# Processing Record 35 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 8 | esperance
# Processing Record 37 of Set 8 | havelock
# Processing Record 38 of Set 8 | gazojak
# Processing Record 39 of Set 8 | severo-kurilsk
# Processing Record 40 of Set 8 | victoria point
# Processing Record 41 of Set 8 | torbat-e jam
# Processing Record 42 of Set 8 | sao mateus
# Processing Record 43 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 8 | luanda
# Processing Record 45 of Set 8 | marsa matruh
# Processing Record 46 of Set 8 | alyangula
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | da nang
# Processing Record 49 of Set 8 | napkor
# Processing Record 50 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 9 | atar
# Processing Record 2 of Set 9 | payson
# Processing Record 3 of Set 9 | onega
# Processing Record 4 of Set 9 | moussoro
# Processing Record 5 of Set 9 | langsa
# Processing Record 6 of Set 9 | penzance
# Processing Record 7 of Set 9 | thompson
# Processing Record 8 of Set 9 | saint anthony
# Processing Record 9 of Set 9 | lakhipur
# Processing Record 10 of Set 9 | mercedes
# Processing Record 11 of Set 9 | santa rosa
# Processing Record 12 of Set 9 | emerald
# Processing Record 13 of Set 9 | sibu
# Processing Record 14 of Set 9 | shubarshi
# Processing Record 15 of Set 9 | iisalmi
# Processing Record 16 of Set 9 | bani
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | ahuimanu
# Processing Record 19 of Set 9 | ulladulla
# Processing Record 20 of Set 9 | jacmel
# Processing Record 21 of Set 9 | udachnyy
# Processing Record 22 of Set 9 | wewak
# Processing Record 23 of Set 9 | komatipoort
# Processing Record 24 of Set 9 | ozark
# Processing Record 25 of Set 9 | rondonopolis
# Processing Record 26 of Set 9 | tazovskiy
# Processing Record 27 of Set 9 | kailua
# Processing Record 28 of Set 9 | dicabisagan
# Processing Record 29 of Set 9 | vanavara
# Processing Record 30 of Set 9 | marsh harbour
# Processing Record 31 of Set 9 | svetlaya
# Processing Record 32 of Set 9 | san jose
# Processing Record 33 of Set 9 | tanda
# Processing Record 34 of Set 9 | marystown
# Processing Record 35 of Set 9 | sembakung
# Processing Record 36 of Set 9 | ambon
# Processing Record 37 of Set 9 | voyvozh
# Processing Record 38 of Set 9 | kaspiysk
# Processing Record 39 of Set 9 | rio gallegos
# Processing Record 40 of Set 9 | pisco
# Processing Record 41 of Set 9 | shingu
# Processing Record 42 of Set 9 | birin
# Processing Record 43 of Set 9 | lac du bonnet
# Processing Record 44 of Set 9 | grenfell
# Processing Record 45 of Set 9 | kamaishi
# Processing Record 46 of Set 9 | hamilton
# Processing Record 47 of Set 9 | payo
# Processing Record 48 of Set 9 | danville
# Processing Record 49 of Set 9 | salta
# Processing Record 50 of Set 9 | nikolskoye
# Processing Record 1 of Set 10 | yar-sale
# Processing Record 2 of Set 10 | invermere
# Processing Record 3 of Set 10 | vestmannaeyjar
# Processing Record 4 of Set 10 | talitsy
# Processing Record 5 of Set 10 | jinchang
# Processing Record 6 of Set 10 | asyut
# Processing Record 7 of Set 10 | manuk mangkaw
# Processing Record 8 of Set 10 | ixtapa
# Processing Record 9 of Set 10 | takoradi
# Processing Record 10 of Set 10 | caborca
# Processing Record 11 of Set 10 | ust-kuyga
# Processing Record 12 of Set 10 | zurrieq
# Processing Record 13 of Set 10 | bulgan
# Processing Record 14 of Set 10 | capreol
# Processing Record 15 of Set 10 | lodja
# Processing Record 16 of Set 10 | boa esperanca
# Processing Record 17 of Set 10 | aksu
# Processing Record 18 of Set 10 | parakou
# Processing Record 19 of Set 10 | morden
# Processing Record 20 of Set 10 | tura
# Processing Record 21 of Set 10 | bethel
# Processing Record 22 of Set 10 | narsaq
# Processing Record 23 of Set 10 | lazaro cardenas
# Processing Record 24 of Set 10 | libreville
# Processing Record 25 of Set 10 | boyolangu
# Processing Record 26 of Set 10 | coos bay
# Processing Record 27 of Set 10 | ylojarvi
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | tari
# Processing Record 30 of Set 10 | nemuro
# Processing Record 31 of Set 10 | puro
# Processing Record 32 of Set 10 | meiningen
# Processing Record 33 of Set 10 | mahanje
# Processing Record 34 of Set 10 | tenenkou
# Processing Record 35 of Set 10 | luena
# Processing Record 36 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | pemangkat
# Processing Record 38 of Set 10 | naze
# Processing Record 39 of Set 10 | ponta delgada
# Processing Record 40 of Set 10 | namtsy
# Processing Record 41 of Set 10 | staraya kulatka
# Processing Record 42 of Set 10 | vardo
# Processing Record 43 of Set 10 | taburao
# City not found. Skipping...
# Processing Record 44 of Set 10 | martapura
# Processing Record 45 of Set 10 | porto velho
# Processing Record 46 of Set 10 | bandundu
# Processing Record 47 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 10 | hun
# Processing Record 49 of Set 10 | port macquarie
# Processing Record 50 of Set 10 | sokoni
# Processing Record 1 of Set 11 | imatra
# Processing Record 2 of Set 11 | nipawin
# Processing Record 3 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 11 | nova praha
# Processing Record 5 of Set 11 | bengkulu
# Processing Record 6 of Set 11 | mackay
# Processing Record 7 of Set 11 | barraute
# Processing Record 8 of Set 11 | bairnsdale
# Processing Record 9 of Set 11 | bilma
# Processing Record 10 of Set 11 | smyrna
# Processing Record 11 of Set 11 | lubaczow
# Processing Record 12 of Set 11 | xining
# Processing Record 13 of Set 11 | san pedro de macoris
# Processing Record 14 of Set 11 | mindelo
# Processing Record 15 of Set 11 | passy
# Processing Record 16 of Set 11 | nur
# Processing Record 17 of Set 11 | nanakuli
# Processing Record 18 of Set 11 | anqing
# Processing Record 19 of Set 11 | svetlyy
# Processing Record 20 of Set 11 | nanyang
# Processing Record 21 of Set 11 | mattru
# Processing Record 22 of Set 11 | oranjestad
# Processing Record 23 of Set 11 | komsomolskiy
# Processing Record 24 of Set 11 | faanui
# Processing Record 25 of Set 11 | abu zabad
# Processing Record 26 of Set 11 | provost
# Processing Record 27 of Set 11 | maua
# Processing Record 28 of Set 11 | honningsvag
# Processing Record 29 of Set 11 | malartic
# Processing Record 30 of Set 11 | copparo
# Processing Record 31 of Set 11 | victoria
# Processing Record 32 of Set 11 | nadym
# Processing Record 33 of Set 11 | jumla
# Processing Record 34 of Set 11 | baijiantan
# Processing Record 35 of Set 11 | panguna
# Processing Record 36 of Set 11 | millinocket
# Processing Record 37 of Set 11 | caxito
# Processing Record 38 of Set 11 | hersbruck
# Processing Record 39 of Set 11 | bathsheba
# Processing Record 40 of Set 11 | breznik
# Processing Record 41 of Set 11 | shitkino
# Processing Record 42 of Set 11 | shenzhen
# Processing Record 43 of Set 11 | alamosa
# Processing Record 44 of Set 11 | nazareno etla
# Processing Record 45 of Set 11 | ayan
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | oudtshoorn
# Processing Record 48 of Set 11 | meulaboh
# Processing Record 49 of Set 11 | bollnas
# Processing Record 50 of Set 11 | candido mendes
# Processing Record 1 of Set 12 | shasta lake
# Processing Record 2 of Set 12 | mizan teferi
# Processing Record 3 of Set 12 | ekhabi
# Processing Record 4 of Set 12 | kamina
# Processing Record 5 of Set 12 | mehamn
# Processing Record 6 of Set 12 | pattan
# Processing Record 7 of Set 12 | qasigiannguit
# Processing Record 8 of Set 12 | nalut
# Processing Record 9 of Set 12 | zeya
# Processing Record 10 of Set 12 | hambantota
# Processing Record 11 of Set 12 | snasa
# Processing Record 12 of Set 12 | sanger
# Processing Record 13 of Set 12 | pevek
# Processing Record 14 of Set 12 | goba
# Processing Record 15 of Set 12 | mashhad
# Processing Record 16 of Set 12 | leningradskiy
# Processing Record 17 of Set 12 | nyuksenitsa
# Processing Record 18 of Set 12 | bondoukou
# Processing Record 19 of Set 12 | catalina foothills
# Processing Record 20 of Set 12 | dryden
# Processing Record 21 of Set 12 | mezen
# Processing Record 22 of Set 12 | iqaluit
# Processing Record 23 of Set 12 | broome
# Processing Record 24 of Set 12 | moroni
# Processing Record 25 of Set 12 | myitkyina
# Processing Record 26 of Set 12 | batagay-alyta
# Processing Record 27 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 12 | kargasok
# Processing Record 29 of Set 12 | nikolsk
# Processing Record 30 of Set 12 | visnes
# Processing Record 31 of Set 12 | ola
# Processing Record 32 of Set 12 | victor harbor
# Processing Record 33 of Set 12 | kibala
# Processing Record 34 of Set 12 | tadine
# Processing Record 35 of Set 12 | toppenish
# Processing Record 36 of Set 12 | mandalgovi
# Processing Record 37 of Set 12 | yarmouth
# Processing Record 38 of Set 12 | narva
# Processing Record 39 of Set 12 | walvis bay
# Processing Record 40 of Set 12 | anadyr
# Processing Record 41 of Set 12 | kieta
# Processing Record 42 of Set 12 | san policarpo
# Processing Record 43 of Set 12 | indianola
# Processing Record 44 of Set 12 | pucallpa
# Processing Record 45 of Set 12 | evensk
# Processing Record 46 of Set 12 | riyadh
# Processing Record 47 of Set 12 | quelimane
# Processing Record 48 of Set 12 | lagoa
# Processing Record 49 of Set 12 | hienghene
# Processing Record 50 of Set 12 | manokwari
# Processing Record 1 of Set 13 | poum
# Processing Record 2 of Set 13 | tomari
# Processing Record 3 of Set 13 | kampong thum
# Processing Record 4 of Set 13 | marathon
# Processing Record 5 of Set 13 | koslan
# Processing Record 6 of Set 13 | nizhniy tsasuchey
# Processing Record 7 of Set 13 | ximei
# Processing Record 8 of Set 13 | amga
# Processing Record 9 of Set 13 | singaparna
# Processing Record 10 of Set 13 | mpika
# Processing Record 11 of Set 13 | kuminskiy
# Processing Record 12 of Set 13 | pando
# Processing Record 13 of Set 13 | te anau
# Processing Record 14 of Set 13 | kupang
# Processing Record 15 of Set 13 | vostok
# Processing Record 16 of Set 13 | caceres
# Processing Record 17 of Set 13 | itarema
# Processing Record 18 of Set 13 | juarez
# Processing Record 19 of Set 13 | celestun
# Processing Record 20 of Set 13 | kantang
# Processing Record 21 of Set 13 | sechura
# Processing Record 22 of Set 13 | holme
# Processing Record 23 of Set 13 | half moon bay
# Processing Record 24 of Set 13 | calabozo
# Processing Record 25 of Set 13 | matara
# Processing Record 26 of Set 13 | vysokogornyy
# Processing Record 27 of Set 13 | caloundra
# Processing Record 28 of Set 13 | luoyang
# Processing Record 29 of Set 13 | sydney
# Processing Record 30 of Set 13 | kerema
# Processing Record 31 of Set 13 | mae sot
# Processing Record 32 of Set 13 | geelong
# Processing Record 33 of Set 13 | assela
# City not found. Skipping...
# Processing Record 34 of Set 13 | jibuti
# Processing Record 35 of Set 13 | autazes
# Processing Record 36 of Set 13 | boende
# Processing Record 37 of Set 13 | santa maria
# Processing Record 38 of Set 13 | koygorodok
# Processing Record 39 of Set 13 | simao
# Processing Record 40 of Set 13 | japura
# Processing Record 41 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 13 | la rioja
# Processing Record 43 of Set 13 | sioux lookout
# Processing Record 44 of Set 13 | griffith
# Processing Record 45 of Set 13 | manono
# Processing Record 46 of Set 13 | calama
# Processing Record 47 of Set 13 | aykhal
# Processing Record 48 of Set 13 | lircay
# Processing Record 49 of Set 13 | liberal
# Processing Record 50 of Set 13 | la ronge
# Processing Record 1 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 14 | byron bay
# Processing Record 3 of Set 14 | nanortalik
# Processing Record 4 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 5 of Set 14 | lukoyanov
# Processing Record 6 of Set 14 | kasongo-lunda
# Processing Record 7 of Set 14 | nome
# Processing Record 8 of Set 14 | cockburn town
# Processing Record 9 of Set 14 | santiago
# Processing Record 10 of Set 14 | ulaangom
# Processing Record 11 of Set 14 | hovd
# Processing Record 12 of Set 14 | tabou
# Processing Record 13 of Set 14 | alakurtti
# Processing Record 14 of Set 14 | sherpur
# Processing Record 15 of Set 14 | auch
# Processing Record 16 of Set 14 | barra
# Processing Record 17 of Set 14 | dhuburi
# Processing Record 18 of Set 14 | sayat
# Processing Record 19 of Set 14 | dwarka
# Processing Record 20 of Set 14 | saint-leu
# Processing Record 21 of Set 14 | moyale
# Processing Record 22 of Set 14 | shwebo
# Processing Record 23 of Set 14 | methoni
# Processing Record 24 of Set 14 | marienburg
# Processing Record 25 of Set 14 | channel-port aux basques
# Processing Record 26 of Set 14 | talnakh
# Processing Record 27 of Set 14 | pandamatenga
# Processing Record 28 of Set 14 | mackenzie
# Processing Record 29 of Set 14 | belaya gora
# Processing Record 30 of Set 14 | santa cruz de la palma
# Processing Record 31 of Set 14 | batouri
# Processing Record 32 of Set 14 | rosarito
# Processing Record 33 of Set 14 | zhigansk
# Processing Record 34 of Set 14 | salinas
# Processing Record 35 of Set 14 | wuda
# Processing Record 36 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 14 | rapar
# Processing Record 38 of Set 14 | kununurra
# Processing Record 39 of Set 14 | dangriga
# Processing Record 40 of Set 14 | umea
# Processing Record 41 of Set 14 | jardim
# Processing Record 42 of Set 14 | leshan
# Processing Record 43 of Set 14 | quatre cocos
# Processing Record 44 of Set 14 | bavly
# Processing Record 45 of Set 14 | santa cruz de tenerife
# Processing Record 46 of Set 14 | amapa
# Processing Record 47 of Set 14 | tynda
# Processing Record 48 of Set 14 | yulara
# Processing Record 49 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 14 | khuzhir
# Processing Record 1 of Set 15 | miraflores
# Processing Record 2 of Set 15 | caraz
# Processing Record 3 of Set 15 | shuangyang
# Processing Record 4 of Set 15 | vila velha
# Processing Record 5 of Set 15 | alghero
# Processing Record 6 of Set 15 | shubarkuduk
# Processing Record 7 of Set 15 | catanzaro
# Processing Record 8 of Set 15 | awjilah
# Processing Record 9 of Set 15 | angoche
# Processing Record 10 of Set 15 | urulga
# City not found. Skipping...
# Processing Record 11 of Set 15 | alekseyevskoye
# Processing Record 12 of Set 15 | nianzishan
# Processing Record 13 of Set 15 | mapua
# Processing Record 14 of Set 15 | puerto colombia
# Processing Record 15 of Set 15 | saint-pierre
# Processing Record 16 of Set 15 | kishtwar
# Processing Record 17 of Set 15 | graaff-reinet
# Processing Record 18 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 19 of Set 15 | verkhnyaya inta
# Processing Record 20 of Set 15 | kloulklubed
# Processing Record 21 of Set 15 | jadu
# Processing Record 22 of Set 15 | huarmey
# Processing Record 23 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 15 | semey
# Processing Record 25 of Set 15 | oistins
# Processing Record 26 of Set 15 | ust-nera
# Processing Record 27 of Set 15 | tres lagoas
# Processing Record 28 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 15 | canby
# Processing Record 30 of Set 15 | moose factory
# Processing Record 31 of Set 15 | bykovo
# Processing Record 32 of Set 15 | tarko-sale
# Processing Record 33 of Set 15 | nampa
# Processing Record 34 of Set 15 | kjollefjord
# Processing Record 35 of Set 15 | farsund
# Processing Record 36 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 15 | rocha
# Processing Record 38 of Set 15 | taihe
# Processing Record 39 of Set 15 | palembang
# Processing Record 40 of Set 15 | robertsport
# Processing Record 41 of Set 15 | linxia
# Processing Record 42 of Set 15 | sendafa
# Processing Record 43 of Set 15 | gander
# Processing Record 44 of Set 15 | asau
# Processing Record 45 of Set 15 | bad aussee
# Processing Record 46 of Set 15 | kuusamo
# Processing Record 47 of Set 15 | gualeguay
# Processing Record 48 of Set 15 | vichuga
# Processing Record 49 of Set 15 | hoa binh
# Processing Record 50 of Set 15 | salgueiro
# Processing Record 1 of Set 16 | bhatkal
# Processing Record 2 of Set 16 | antalaha
# Processing Record 3 of Set 16 | skibbereen
# Processing Record 4 of Set 16 | kiruna
# Processing Record 5 of Set 16 | matay
# Processing Record 6 of Set 16 | talara
# Processing Record 7 of Set 16 | dukat
# Processing Record 8 of Set 16 | kharp
# Processing Record 9 of Set 16 | coromandel
# Processing Record 10 of Set 16 | bella vista
# Processing Record 11 of Set 16 | sao jose da coroa grande
# Processing Record 12 of Set 16 | tambun
# Processing Record 13 of Set 16 | santa cruz del sur
# Processing Record 14 of Set 16 | takaka
# Processing Record 15 of Set 16 | kysyl-syr
# Processing Record 16 of Set 16 | abyek
# Processing Record 17 of Set 16 | belyy yar
# Processing Record 18 of Set 16 | uhlove
# Processing Record 19 of Set 16 | dunedin
# Processing Record 20 of Set 16 | itupiranga
# Processing Record 21 of Set 16 | ostersund
# Processing Record 22 of Set 16 | banihal
# Processing Record 23 of Set 16 | antofagasta
# Processing Record 24 of Set 16 | namibe
# Processing Record 25 of Set 16 | forest
# Processing Record 26 of Set 16 | si satchanalai
# Processing Record 27 of Set 16 | gao
# Processing Record 28 of Set 16 | harper
# Processing Record 29 of Set 16 | gorontalo
# Processing Record 30 of Set 16 | hvide sande
# Processing Record 31 of Set 16 | katherine
# Processing Record 32 of Set 16 | thinadhoo
# Processing Record 33 of Set 16 | sompeta
# Processing Record 34 of Set 16 | malatya
# Processing Record 35 of Set 16 | traiguen
# Processing Record 36 of Set 16 | pasil
# Processing Record 37 of Set 16 | higuey
# City not found. Skipping...
# Processing Record 38 of Set 16 | sisimiut
# Processing Record 39 of Set 16 | patiya
# Processing Record 40 of Set 16 | imperia
# Processing Record 41 of Set 16 | san patricio
# Processing Record 42 of Set 16 | lima
# -----------------------------
# Data Retrieval Complete
# -----------------------------
